# %%
import pandas as p

# %%
df=p.read_csv("students.csv")
df
# Out:
#      ID      NAME BRANCH  CGPA  MARKS    FEE GENDER
# 0   596    bhagya    cse  9.50    450   1000      F
# 1   766      teja    ece  9.70    470   2000      M
# 2   566      raju     me  9.40    445   4200      M
# 3   373  poojitha    cse  9.72    478   3000      F
# 4   543     sunny     me  9.50    450   5000      M
# 5   992      neha    ece  9.89    490  23535      F
# 6   786    naveen    eee  9.90    495  20000      M
# 7   305     satya     ce  9.74    479  56457      F
# 8   999     sailu    eee  9.80    480   7567      F
# 9   839    chinna     ce  9.60    468   4020      M
# 10  101    sweety     me  9.20    400  10000      F
# 11  345      nani    cse  9.70    475   3000      M
# 12  420    geetha    cse  9.70    470  68568      F
# 13  191   sumathi     ce  9.89    490   5754      F
# 14  895     madhu     ce  9.75    475   6765      F
# 15  425   dharani    ece  9.95    495   5677      F

# %% [markdown]
# # Handling Missig Values:

# %%
data=p.DataFrame({"Name":["python","c","c++","Java"],"Id":[1,None,3,4]})

# %%
print(data)
# Out:
#      Name   Id
# 0  python  1.0
# 1       c  NaN
# 2     c++  3.0
# 3    Java  4.0

# %%
data.dropna()
# Out:
#      Name   Id
# 0  python  1.0
# 2     c++  3.0
# 3    Java  4.0

# %%
data
# Out:
#      Name   Id
# 0  python  1.0
# 1       c  NaN
# 2     c++  3.0
# 3    Java  4.0

# %%
data.dropna(inplace=False)
# Out:
#      Name   Id
# 0  python  1.0
# 2     c++  3.0
# 3    Java  4.0

# %%
data
# Out:
#      Name   Id
# 0  python  1.0
# 1       c  NaN
# 2     c++  3.0
# 3    Java  4.0

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#      Name   Id
# 0  python  1.0
# 2     c++  3.0
# 3    Java  4.0

# %%
data["Number"]=[None,20,None]

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.drop(["Number"],axis=1)
# Out:
#      Name   Id
# 0  python  1.0
# 2     c++  3.0
# 3    Java  4.0

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %% [markdown]
# # Data Normalization:

# %%
df
# Out:
#     ID      NAME BRANCH  CGPA  MARKS        FEE
# 0  596    bhagya    cse  9.50    450       1000
# 1  766      teja    ece  9.70    470       2000
# 2  373  poojitha    cse  9.72    478  2,425,346
# 3  992      neha    ece  9.89    490      23535
# 4  305     satya     ce  9.74    479      56457
# 5  999     sailu    eee  9.80    480       7567
# 6  420    geetha    cse  9.70    470      68568
# 7  191   sumathi     ce  9.89    490       5754
# 8  895     madhu     ce  9.75    475       6765
# 9  425   dharani    ece  9.95    495       5677

# %%
df[df["MARKS"]==df["MARKS"].min()]
# Out:
#     ID    NAME BRANCH  CGPA  MARKS   FEE
# 0  596  bhagya    cse   9.5    450  1000

# %%
df["New_marks"]=((df["MARKS"])-(df["MARKS"].min()))/((df["MARKS"].max())-(df["MARKS"].min()))

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df["New_cgpa"]=df["CGPA"]/df["CGPA"].max()

# %%
df
# Out:
#     ID      NAME BRANCH  CGPA  MARKS        FEE  New_marks  New_cgpa
# 0  596    bhagya    cse  9.50    450       1000   0.000000  0.954774
# 1  766      teja    ece  9.70    470       2000   0.444444  0.974874
# 2  373  poojitha    cse  9.72    478  2,425,346   0.622222  0.976884
# 3  992      neha    ece  9.89    490      23535   0.888889  0.993970
# 4  305     satya     ce  9.74    479      56457   0.644444  0.978894
# 5  999     sailu    eee  9.80    480       7567   0.666667  0.984925
# 6  420    geetha    cse  9.70    470      68568   0.444444  0.974874
# 7  191   sumathi     ce  9.89    490       5754   0.888889  0.993970
# 8  895     madhu     ce  9.75    475       6765   0.555556  0.979899
# 9  425   dharani    ece  9.95    495       5677   1.000000  1.000000

# %%
df["N_M_S"]=(df["MARKS"]-df["MARKS"].mean())/df["MARKS"].std()

# %%
df
# Out:
#     ID      NAME BRANCH  CGPA  MARKS        FEE  New_marks  New_cgpa     N_M_S
# 0  596    bhagya    cse  9.50    450       1000   0.000000  0.954774 -2.144132
# 1  766      teja    ece  9.70    470       2000   0.444444  0.974874 -0.596022
# 2  373  poojitha    cse  9.72    478  2,425,346   0.622222  0.976884  0.023222
# 3  992      neha    ece  9.89    490      23535   0.888889  0.993970  0.952088
# 4  305     satya     ce  9.74    479      56457   0.644444  0.978894  0.100627
# 5  999     sailu    eee  9.80    480       7567   0.666667  0.984925  0.178033
# 6  420    geetha    cse  9.70    470      68568   0.444444  0.974874 -0.596022
# 7  191   sumathi     ce  9.89    490       5754   0.888889  0.993970  0.952088
# 8  895     madhu     ce  9.75    475       6765   0.555556  0.979899 -0.208995
# 9  425   dharani    ece  9.95    495       5677   1.000000  1.000000  1.339115

# %% [markdown]
# # Data Handling:

# %%
import numpy as n

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.replace(to_replace=[1],value=2)
# Out:
#      Name   Id  Number
# 0  python  2.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.replace(to_replace=[2,3],value=[1,2])
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  2.0    20.0
# 3    Java  4.0     NaN

# %%
data.replace([1,2],[2,3])
# Out:
#      Name   Id  Number
# 0  python  2.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.replace(to_replace=n.NaN,value=0)
# Out:
#      Name   Id  Number
# 0  python  1.0     0.0
# 2     c++  3.0    20.0
# 3    Java  4.0     0.0

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.replace(to_replace=2,value=1)
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.fillna(0)
# Out:
#      Name   Id  Number
# 0  python  1.0     0.0
# 2     c++  3.0    20.0
# 3    Java  4.0     0.0

# %%
data
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data["Year"]=[2020,None,2022]

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0     NaN
# 3    Java  4.0     NaN  2022.0

# %%
data.fillna(0)
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     0.0  2020.0
# 2     c++  3.0    20.0     0.0
# 3    Java  4.0     0.0  2022.0

# %%
data["Year"]=data["Year"].fillna(2021)

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0  2021.0
# 3    Java  4.0     NaN  2022.0

# %%
data.replace(2021,n.NaN)
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0     NaN
# 3    Java  4.0     NaN  2022.0

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0  2021.0
# 3    Java  4.0     NaN  2022.0

# %%
data["Year"]=data["Year"].fillna(2021)

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0  2021.0
# 3    Java  4.0     NaN  2022.0

# %%
data.drop(0)
# Out:
#    Name   Id  Number    Year
# 2   c++  3.0    20.0  2021.0
# 3  Java  4.0     NaN  2022.0

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0  2021.0
# 3    Java  4.0     NaN  2022.0

# %%
data.drop(data.columns[3],axis=1)
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.drop(["Year"],axis=1)
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data.drop(data.columns[[2,3]],axis=1)
# Out:
#      Name   Id
# 0  python  1.0
# 2     c++  3.0
# 3    Java  4.0

# %%
data.drop(["Id","Year"],axis=1)
# Out:
#      Name  Number
# 0  python     NaN
# 2     c++    20.0
# 3    Java     NaN

# %%
data.drop(data.columns[[3]],axis=1)
# Out:
#      Name   Id  Number
# 0  python  1.0     NaN
# 2     c++  3.0    20.0
# 3    Java  4.0     NaN

# %%
data
# Out:
#      Name   Id  Number    Year
# 0  python  1.0     NaN  2020.0
# 2     c++  3.0    20.0  2021.0
# 3    Java  4.0     NaN  2022.0
