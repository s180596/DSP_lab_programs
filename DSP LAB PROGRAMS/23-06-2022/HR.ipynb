# %%
import pandas as p

# %%
df=p.read_csv("HR.csv")

# %%
df
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
df.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# ...

# %%
df.describe()
# Out:
#              Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count     100.00000   100.000000      100.000000       100.000000
# mean   547652.10000    39.238700       58.080000      2008.120000
# std    257664.16679    12.066252       12.294106         8.642484
# min    134841.00000    21.100000       40.000000      1983.000000
# 25%    328643.75000    28.177500       50.000000      2003.000000
# 50%    497414.00000    37.595000       56.000000      2010.500000
# 75%    766040.00000    49.900000       61.250000      2015.000000
# max    979607.00000    59.470000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count        100.000000      100.000000              100.000000
# mean           6.250000       16.370000                8.978400
# std            3.453515        9.403046                8.657358
# min            1.000000        1.000000                0.020000
# ...

# %%
df.to_excel("HR1.xlsx",sheet_name="S1",index=False)

# %%
d=p.read_excel("HR1.xlsx")
d
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 37 columns):
# Emp ID                    100 non-null int64
# Name Prefix               100 non-null object
# First Name                100 non-null object
# Middle Initial            100 non-null object
# Last Name                 100 non-null object
# Gender                    100 non-null object
# E Mail                    100 non-null object
# Father's Name             100 non-null object
# Mother's Name             100 non-null object
# Mother's Maiden Name      100 non-null object
# Date of Birth             100 non-null object
# Time of Birth             100 non-null object
# Age in Yrs.               100 non-null float64
# Weight in Kgs.            100 non-null int64
# Date of Joining           100 non-null object
# Quarter of Joining        100 non-null object
# Half of Joining           100 non-null object
# Year of Joining           100 non-null int64
# ...

# %%
df[["City","E Mail","Emp ID"]]
# Out:
#             City                        E Mail  Emp ID
# 0         Denver       lois.walker@hotmail.com  677509
# 1      Stonewall     brenda.robinson@gmail.com  940761
# 2   Michigantown        joe.robinson@gmail.com  428945
# 3       Hydetown         diane.evans@yahoo.com  408351
# 4        Fremont  benjamin.russell@charter.net  193819
# ..           ...                           ...     ...
# 95        Biloxi         jose.hill@hotmail.com  639892
# 96  Carol Stream       harold.nelson@gmail.com  704709
# 97       Detroit         nicole.ward@yahoo.com  461593
# 98      Mc Grath      theresa.murphy@gmail.com  392491
# 99          Alma       tammy.young@comcast.net  495141
#
# [100 rows x 3 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (100, 37)

# %%
df[df["Day of Joining"]>20]
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 12  386158        Mrs.    Melissa              Q        King      F
# 14  441771        Mrs.     Cheryl              O       Scott      F
# 15  528509        Hon.      Paula              G        Diaz      F
# 18  890290        Hon.      Julia              S       Scott      F
# 20  979607         Ms.      Carol              J     Edwards      F
# 22  426038        Hon.       Joan              C     Stewart      F
# 23  388642        Mrs.       Ruby              R      Rogers      F
# ...

# %%
df[df["Day of Joining"].isin([21,22])]
# Out:
#     Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 5   499687         Mr.    Patrick              F     Bailey      M
# 15  528509        Hon.      Paula              G       Diaz      F
# 35  333476        Hon.       Mary              P     Wilson      F
# 50  958326         Mr.      Larry              T     Miller      M
# 62  758872         Mr.      Henry              Y    Jenkins      M
# 70  915638         Dr.      Jason              W   Anderson      M
# 78  806955         Mr.    William              G  Hernandez      M
#
#                               E Mail     Father's Name      Mother's Name  \
# 5             patrick.bailey@aol.com      Ralph Bailey       Laura Bailey
# 15              paula.diaz@gmail.com         Alan Diaz       Kathryn Diaz
# 35         mary.wilson@sbcglobal.net     Robert Wilson    Jennifer Wilson
# 50            larry.miller@shell.com    Russell Miller     Mildred Miller
# ...

# %%
df[df["Day of Joining"].isin([21,22])][["Day of Joining"]]
# Out:
#     Day of Joining
# 5               22
# 15              22
# 35              22
# 50              22
# 62              21
# 70              21
# 78              21

# %%
df["DOW of Joining"]
# Out:
# 0        Monday
# 1        Sunday
# 2     Wednesday
# 3        Friday
# 4      Thursday
#         ...
# 95     Saturday
# 96      Tuesday
# 97       Monday
# 98      Tuesday
# 99     Saturday
# Name: DOW of Joining, Length: 100, dtype: object

# %%
df[(df["Day of Joining"].isin([20,21]))|(df["DOW of Joining"]=="Monday")]
# Out:
#     Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0   677509        Drs.       Lois              H     Walker      F
# 9   162402        Hon.      Diana              T   Peterson      F
# 14  441771        Mrs.     Cheryl              O      Scott      F
# 15  528509        Hon.      Paula              G       Diaz      F
# 16  912990         Mr.     Joshua              T    Stewart      M
# 17  214352         Ms.    Theresa              G        Lee      F
# 20  979607         Ms.      Carol              J    Edwards      F
# 29  335732         Ms.     Brenda              M     Butler      F
# 30  329752        Hon.    Lillian              X      Brown      F
# 40  923947         Ms.       Mary              G     Bryant      F
# 57  515103         Ms.       Anne              A      Perez      F
# 59  750173         Mr.    Antonio              R    Roberts      M
# 60  687017         Ms.    Frances              P     Watson      F
# ...

# %%
df.loc[(df["Day of Joining"].isin([21,22])),["Emp ID"]]
# Out:
#     Emp ID
# 5   499687
# 15  528509
# 35  333476
# 50  958326
# 62  758872
# 70  915638
# 78  806955

# %%
df.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %%
df=df.rename(columns={"Emp ID":"ID"})

# %%
df["Age in Yrs."].mean()
# Out:
# 39.23870000000001

# %%
df
# Out:
#         ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
df[["ID","Age in Yrs."]]
# Out:
#         ID  Age in Yrs.
# 0   677509        36.36
# 1   940761        47.02
# 2   428945        54.15
# 3   408351        39.67
# 4   193819        40.31
# ..     ...          ...
# 95  639892        22.82
# 96  704709        32.61
# 97  461593        52.66
# 98  392491        29.60
# 99  495141        38.38
#
# [100 rows x 2 columns]

# %%
df.agg({"Age in Yrs.":["min","max"],"Weight in Kgs.":["mean","median"]})
# Out:
#         Age in Yrs.  Weight in Kgs.
# max           59.47             NaN
# mean            NaN           58.08
# median          NaN           56.00
# min           21.10             NaN

# %%
df["Quarter of Joining"].unique()
# Out:
# array(['Q4', 'Q3', 'Q2', 'Q1'], dtype=object)

# %%
df["Quarter of Joining"].value_counts()
# Out:
# Q3    32
# Q1    26
# Q2    23
# Q4    19
# Name: Quarter of Joining, dtype: int64

# %%
df["Quarter of Joining"].unique()
# Out:
# array(['Q4', 'Q3', 'Q2', 'Q1'], dtype=object)

# %%
df.sort_values(by="Weight in Kgs.").head()
# Out:
#         ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 41  227922        Hon.     Amanda              M     Hughes      F
# 7   380086        Mrs.      Carol              V     Murphy      F
# 75  765850        Mrs.      Linda              R      Moore      F
# 47  524896         Ms.       Judy              Y  Hernandez      F
# 51  447813        Mrs.        Ann              Q    Coleman      F
#
#                           E Mail   Father's Name     Mother's Name  \
# 41  amanda.hughes@rediffmail.com      Roy Hughes    Cynthia Hughes
# 7         carol.murphy@gmail.com   Eugene Murphy  Katherine Murphy
# 75         linda.moore@gmail.com    Howard Moore       Diana Moore
# 47      judy.hernandez@gmail.com  Fred Hernandez  Pamela Hernandez
# 51           ann.coleman@ibm.com  Harold Coleman      Tina Coleman
#
#    Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 41               Bryant  ...  311-35-2540  225-544-9700  Lake Charles
# ...
