# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cardiovascular.txt",sep=';')
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd
# 0     52    1
# 1     63    1
# 2     46    0
# ...

# %% [markdown]
# # 13

# %%
df.shape
# Out:
# (462, 11)

# %%
df.shape[0]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 11 columns):
# ind          462 non-null int64
# sbp          462 non-null int64
# tobacco      462 non-null float64
# ldl          462 non-null float64
# adiposity    462 non-null float64
# famhist      462 non-null object
# typea        462 non-null int64
# obesity      462 non-null float64
# alcohol      462 non-null float64
# age          462 non-null int64
# chd          462 non-null int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 39.8+ KB

# %% [markdown]
# # 14

# %%
a=df.groupby(["chd"])

# %%
a.groups
# Out:
# {0: Int64Index([  2,   5,   6,   8,  12,  13,  14,  15,  16,  21,
#              ...
#              445, 447, 448, 450, 451, 452, 456, 457, 459, 460],
#             dtype='int64', length=302),
#  1: Int64Index([  0,   1,   3,   4,   7,   9,  10,  11,  17,  18,
#              ...
#              422, 423, 424, 446, 449, 453, 454, 455, 458, 461],
#             dtype='int64', length=160)}

# %%
a.get_group("")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-211821305e51> in <module>
# ----> 1 a.get_group("")
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     678         inds = self._get_index(name)
#     679         if not len(inds):
# --> 680             raise KeyError(name)
#     681
#     682         return obj.take(inds, axis=self.axis)
#
# KeyError: ''

# %% [markdown]
# # 15

# %%
from scipy.stats import pearsonr

# %%
corr,_=pearsonr(df["age"],df["sbp"])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.389

# %%
plt.bar(df["age"],df["sbp"])
# Out:
# <BarContainer object of 462 artists>

# %%
df["age"].corr(df["sbp"])
# Out:
# 0.3887705972765734

# %%
plt.plot(df["age"],df["sbp"])

# %%
plt.scatter(df["age"],df["sbp"])

# %% [markdown]
# # 16

# %%
df.columns
# Out:
# Index(['ind', 'sbp', 'tobacco', 'ldl', 'adiposity', 'famhist', 'typea',
#        'obesity', 'alcohol', 'age', 'chd'],
#       dtype='object')

# %%
plt.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-1516a20b26b1> in <module>
# ----> 1 plt.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# # 17

# %%
d=df[["sbp","obesity","age","ldl"]]

# %%
sns.heatmap(d.corr(),annot=True)

# %%
sns.pairplot(d)

# %% [markdown]
# # 18

# %%
df[df["age"]<15]
# Out:
# Empty DataFrame
# Columns: [ind, sbp, tobacco, ldl, adiposity, famhist, typea, obesity, alcohol, age, chd]
# Index: []

# %%
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd
# 0     52    1
# 1     63    1
# 2     46    0
# ...

# %%
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd
# 0     52    1
# 1     63    1
# 2     46    0
# ...

# %% [markdown]
# # 19

# %%
l=[]
for r in df["age"]:
    if(r<15):
        l.append("young")
    elif((r>=15) & (r<35)):
        l.append("adult")
    elif((r>=35) & (r<55)):
        l.append("mid")
    else:
        l.append("old")
df["agegroup"]=l

# %%
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd agegroup
# 0     52    1      mid
# ...

# %%
p=pd.crosstab(df["chd"],df["agegroup"],margins=True)
p
# Out:
# agegroup  adult  mid  old  All
# chd
# 0           125  118   59  302
# 1            18   71   71  160
# All         143  189  130  462

# %%
df.sort_values(by=["agegroup"])
# Out:
#      ind  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  \
# 234  235  138     0.00  3.24      27.68   Absent     60    25.70    88.66
# 365  367  132     0.72  4.37      19.54   Absent     48    26.11    49.37
# 103  104  128     0.42  4.60      26.68   Absent     41    30.97    10.33
# 104  105  118     1.50  5.38      25.84   Absent     64    28.63     3.89
# 194  195  138     0.05  2.79      10.35   Absent     46    21.62     0.00
# ..   ...  ...      ...   ...        ...      ...    ...      ...      ...
# 334  336  146     1.35  6.39      34.21   Absent     51    26.43     0.00
# 336  338  130     7.28  3.56      23.29  Present     20    26.80    51.87
# 337  339  138     6.00  7.24      37.05   Absent     38    28.69     0.00
# 323  325  140     8.60  3.90      32.16  Present     52    28.51    11.11
# 230  231  110     2.35  3.36      26.72  Present     54    26.08   109.80
#
#      age  chd agegroup
# 234   29    0    adult
# 365   28    0    adult
# ...

# %%
q=p.iloc[1,:]
print(pd.DataFrame(q))
# Out:
#             1
# agegroup
# adult      18
# mid        71
# old        71
# All       160
# <class 'pandas.core.series.Series'>

# %%
df
# Out:
#      ind  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  alcohol  \
# 0      1  160    12.00   5.73      23.11  Present     49    25.30    97.20
# 1      2  144     0.01   4.41      28.61   Absent     55    28.87     2.06
# 2      3  118     0.08   3.48      32.28  Present     52    29.14     3.81
# 3      4  170     7.50   6.41      38.03  Present     51    31.99    24.26
# 4      5  134    13.60   3.50      27.78  Present     60    25.99    57.34
# ..   ...  ...      ...    ...        ...      ...    ...      ...      ...
# 457  459  214     0.40   5.98      31.72   Absent     64    28.45     0.00
# 458  460  182     4.20   4.41      32.10   Absent     52    28.61    18.72
# 459  461  108     3.00   1.59      15.23   Absent     40    20.09    26.64
# 460  462  118     5.40  11.61      30.79   Absent     64    27.35    23.97
# 461  463  132     0.00   4.82      33.41  Present     62    14.70     0.00
#
#      age  chd agegroup
# 0     52    1      mid
# ...

# %% [markdown]
# # 20

# %%
d=df.groupby("agegroup").mean()[["ldl"]]
print(d)
# Out:
#                ldl
# agegroup
# adult     3.841119
# mid       5.097143
# old       5.210692

# %%
plt.boxplot(d["ldl"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a0ade73b88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a0ade73d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a0ade73388>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a0ade79fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a0ade79d48>],
#  'means': []}
